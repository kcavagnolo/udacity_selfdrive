# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# %%
class Layer:
    """
    Base class for layers in the network.
    Arguments:
        `inbound_layers`: A list of layers with edges into this layer.
    """
    def __init__(self, inbound_layers=[]):
        """
        Layer's constructor (runs when the object is instantiated). Sets
        properties that all layers need.
        """
        # A list of layers with edges into this layer.
        self.inbound_layers = inbound_layers
        # The eventual value of this layer. Set by running
        # the forward() method.
        self.value = None
        # A list of layers that this layer outputs to.
        self.outbound_layers = []
        # New property! Keys are the inputs to this layer and
        # their values are the partials of this layer with
        # respect to that input.
        self.gradients = {}
        # Sets this layer as an outbound layer for all of
        # this layer's inputs.
        for layer in inbound_layers:
            layer.outbound_layers.append(self)

    def forward():
        """
        Every layer that uses this class as a base class will
        need to define its own `forward` method.
        """
        raise NotImplementedError

    def backward():
        """
        Every layer that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError

# %%
class Input(Layer):
    """
    A generic input into the network.
    """
    def __init__(self):
        # The base class constructor has to run to set all
        # the properties here.
        #
        # The most important property on an Input is value.
        # self.value is set during `topological_sort` later.
        Layer.__init__(self)

    def forward(self):
        # Do nothing because nothing is calculated.
        pass

    def backward(self):
        # An Input layer has no inputs so the gradient (derivative)
        # is zero.
        # The key, `self`, is reference to this object.
        self.gradients = {self: 0}
        # Weights and bias may be inputs, so you need to sum
        # the gradient from output gradients.
        for n in self.outbound_layers:
            self.gradients[self] += n.gradients[self]

# %%
class Linear(Layer):
    """
    Represents a layer that performs a linear transform.
    """
    def __init__(self, X, W, b):
        # The base class (Layer) constructor. Weights and bias
        # are treated like inbound layers.
        Layer.__init__(self, [X, W, b])

    def forward(self):
        """
        Performs the math behind a linear transform.
        """
        X = self.inbound_layers[0].value
        W = self.inbound_layers[1].value
        b = self.inbound_layers[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_layers.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_layers}
        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_layers:
            # Get the partial of the cost with respect to this layer.
            grad_cost = n.gradients[self]
            # Set the partial of the loss with respect to this layer's inputs.
            self.gradients[self.inbound_layers[0]] += np.dot(grad_cost, self.inbound_layers[1].value.T)
            # Set the partial of the loss with respect to this layer's weights.
            self.gradients[self.inbound_layers[1]] += np.dot(self.inbound_layers[0].value.T, grad_cost)
            # Set the partial of the loss with respect to this layer's bias.
            self.gradients[self.inbound_layers[2]] += np.sum(grad_cost, axis=0, keepdims=False)

# %%
class Sigmoid(Layer):
    """
    Represents a layer that performs the sigmoid activation function.
    """
    def __init__(self, layer):
        # The base class constructor.
        Layer.__init__(self, [layer])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used with `backward` as well.

        `x`: A numpy array-like object.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Perform the sigmoid function and set the value.
        """
        input_value = self.inbound_layers[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        """
        Calculates the gradient using the derivative of
        the sigmoid function.
        """
        # Initialize the gradients to 0.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_layers}
        # Sum the partial with respect to the input over all the outputs.
        for n in self.outbound_layers:
            grad_cost = n.gradients[self]
            sigmoid = self.value
            self.gradients[self.inbound_layers[0]] += sigmoid * (1 - sigmoid) * grad_cost

# %%
class MSE(Layer):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last layer for a network.
        """
        # Call the base class' constructor.
        Layer.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_layers[0].value.reshape(-1, 1)
        a = self.inbound_layers[1].value.reshape(-1, 1)

        self.m = self.inbound_layers[0].value.shape[0]
        # Save the computed output for backward.
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        """
        Calculates the gradient of the cost.
        """
        self.gradients[self.inbound_layers[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_layers[1]] = (-2 / self.m) * self.diff

# %%
def topological_sort(feed_dict):
    """
    Sort the layers in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Layer and the value is the respective value feed to that Layer.

    Returns a list of sorted layers.
    """

    input_layers = [n for n in feed_dict.keys()]

    G = {}
    layers = [n for n in input_layers]
    while len(layers) > 0:
        n = layers.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_layers:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            layers.append(m)

    L = []
    S = set(input_layers)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_layers:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L

# %%
def forward_and_backward(graph):
    """
    Performs a forward pass and a backward pass through a list of sorted Layers.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # see: https://docs.python.org/2.3/whatsnew/section-slices.html
    for n in graph[::-1]:
        n.backward()

# %%
def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Layers representing weights/biases.
        `learning_rate`: The learning rate.
    """
    for t in trainables:
        t.value -= learning_rate * t.gradients[t]

# %%
# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

# %%
# setup nn
n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# create layers
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

# fill layers
l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

# %%
# Total number of examples
epochs = 1000
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

# topo sort
feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}
graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]
print("Total number of examples = {}".format(m))
# Out:
# Total number of examples = 506

# %%
# sgd
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)
        loss += graph[-1].value
    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Epoch: 1, Loss: 16.278
# Epoch: 2, Loss: 10.387
# Epoch: 3, Loss: 11.923
# Epoch: 4, Loss: 15.284
# Epoch: 5, Loss: 16.088
# Epoch: 6, Loss: 12.603
# Epoch: 7, Loss: 11.448
# Epoch: 8, Loss: 11.420
# Epoch: 9, Loss: 11.186
# Epoch: 10, Loss: 10.955
# Epoch: 11, Loss: 9.162
# Epoch: 12, Loss: 9.022
# Epoch: 13, Loss: 10.580
# Epoch: 14, Loss: 8.098
# Epoch: 15, Loss: 11.085
# Epoch: 16, Loss: 11.015
# Epoch: 17, Loss: 9.774
# Epoch: 18, Loss: 7.762
# Epoch: 19, Loss: 9.653
# Epoch: 20, Loss: 9.059
# Epoch: 21, Loss: 8.184
# Epoch: 22, Loss: 9.405
# Epoch: 23, Loss: 8.895
# Epoch: 24, Loss: 7.297
# Epoch: 25, Loss: 8.675
# Epoch: 26, Loss: 9.905
# Epoch: 27, Loss: 7.367
# Epoch: 28, Loss: 8.517
# Epoch: 29, Loss: 6.856
# Epoch: 30, Loss: 9.895
# Epoch: 31, Loss: 7.334
# Epoch: 32, Loss: 7.817
# Epoch: 33, Loss: 7.440
# Epoch: 34, Loss: 7.533
# Epoch: 35, Loss: 7.404
# Epoch: 36, Loss: 6.813
# Epoch: 37, Loss: 10.338
# Epoch: 38, Loss: 8.240
# Epoch: 39, Loss: 8.838
# Epoch: 40, Loss: 7.977
# Epoch: 41, Loss: 6.979
# Epoch: 42, Loss: 7.992
# Epoch: 43, Loss: 6.774
# Epoch: 44, Loss: 6.441
# Epoch: 45, Loss: 7.390
# Epoch: 46, Loss: 7.792
# Epoch: 47, Loss: 8.594
# Epoch: 48, Loss: 7.817
# Epoch: 49, Loss: 6.735
# Epoch: 50, Loss: 7.596
# Epoch: 51, Loss: 6.258
# Epoch: 52, Loss: 6.708
# Epoch: 53, Loss: 6.465
# Epoch: 54, Loss: 8.020
# Epoch: 55, Loss: 7.893
# Epoch: 56, Loss: 7.848
# Epoch: 57, Loss: 7.744
# Epoch: 58, Loss: 6.401
# Epoch: 59, Loss: 7.034
# Epoch: 60, Loss: 7.666
# Epoch: 61, Loss: 6.528
# Epoch: 62, Loss: 7.307
# Epoch: 63, Loss: 6.257
# Epoch: 64, Loss: 5.296
# Epoch: 65, Loss: 6.953
# Epoch: 66, Loss: 7.696
# Epoch: 67, Loss: 8.182
# Epoch: 68, Loss: 5.211
# Epoch: 69, Loss: 6.197
# Epoch: 70, Loss: 6.360
# Epoch: 71, Loss: 5.888
# Epoch: 72, Loss: 7.094
# Epoch: 73, Loss: 7.102
# Epoch: 74, Loss: 5.416
# Epoch: 75, Loss: 7.578
# Epoch: 76, Loss: 6.872
# Epoch: 77, Loss: 6.432
# Epoch: 78, Loss: 4.891
# Epoch: 79, Loss: 6.250
# Epoch: 80, Loss: 6.144
# Epoch: 81, Loss: 7.391
# Epoch: 82, Loss: 6.188
# Epoch: 83, Loss: 5.523
# Epoch: 84, Loss: 5.845
# Epoch: 85, Loss: 6.523
# Epoch: 86, Loss: 6.772
# Epoch: 87, Loss: 6.813
# Epoch: 88, Loss: 6.167
# Epoch: 89, Loss: 6.342
# Epoch: 90, Loss: 5.981
# Epoch: 91, Loss: 6.262
# Epoch: 92, Loss: 6.571
# Epoch: 93, Loss: 6.719
# Epoch: 94, Loss: 6.893
# Epoch: 95, Loss: 6.899
# Epoch: 96, Loss: 6.287
# Epoch: 97, Loss: 7.485
# Epoch: 98, Loss: 6.045
# Epoch: 99, Loss: 6.459
# Epoch: 100, Loss: 6.476
# Epoch: 101, Loss: 6.808
# Epoch: 102, Loss: 5.454
# Epoch: 103, Loss: 6.670
# Epoch: 104, Loss: 6.978
# Epoch: 105, Loss: 7.077
# Epoch: 106, Loss: 5.861
# Epoch: 107, Loss: 6.165
# Epoch: 108, Loss: 5.742
# Epoch: 109, Loss: 6.212
# Epoch: 110, Loss: 6.541
# Epoch: 111, Loss: 5.518
# Epoch: 112, Loss: 6.514
# Epoch: 113, Loss: 5.167
# Epoch: 114, Loss: 6.648
# Epoch: 115, Loss: 7.347
# Epoch: 116, Loss: 7.074
# Epoch: 117, Loss: 5.060
# Epoch: 118, Loss: 6.501
# Epoch: 119, Loss: 5.672
# Epoch: 120, Loss: 5.399
# Epoch: 121, Loss: 5.058
# Epoch: 122, Loss: 6.007
# Epoch: 123, Loss: 5.668
# Epoch: 124, Loss: 6.542
# Epoch: 125, Loss: 6.023
# Epoch: 126, Loss: 6.424
# Epoch: 127, Loss: 5.687
# Epoch: 128, Loss: 6.066
# Epoch: 129, Loss: 6.231
# Epoch: 130, Loss: 5.351
# Epoch: 131, Loss: 6.032
# Epoch: 132, Loss: 5.185
# Epoch: 133, Loss: 5.383
# Epoch: 134, Loss: 4.782
# Epoch: 135, Loss: 5.423
# Epoch: 136, Loss: 6.106
# Epoch: 137, Loss: 6.176
# Epoch: 138, Loss: 5.569
# Epoch: 139, Loss: 5.063
# Epoch: 140, Loss: 5.398
# Epoch: 141, Loss: 5.878
# Epoch: 142, Loss: 5.606
# Epoch: 143, Loss: 5.733
# Epoch: 144, Loss: 5.454
# Epoch: 145, Loss: 5.345
# Epoch: 146, Loss: 5.153
# Epoch: 147, Loss: 4.941
# Epoch: 148, Loss: 5.607
# Epoch: 149, Loss: 4.828
# Epoch: 150, Loss: 5.698
# Epoch: 151, Loss: 5.959
# Epoch: 152, Loss: 5.276
# Epoch: 153, Loss: 5.683
# Epoch: 154, Loss: 5.747
# Epoch: 155, Loss: 5.574
# Epoch: 156, Loss: 5.596
# Epoch: 157, Loss: 5.337
# Epoch: 158, Loss: 5.562
# Epoch: 159, Loss: 5.537
# Epoch: 160, Loss: 5.509
# Epoch: 161, Loss: 4.892
# Epoch: 162, Loss: 5.731
# Epoch: 163, Loss: 5.833
# Epoch: 164, Loss: 5.949
# Epoch: 165, Loss: 5.230
# Epoch: 166, Loss: 5.890
# Epoch: 167, Loss: 4.391
# Epoch: 168, Loss: 5.842
# Epoch: 169, Loss: 5.018
# Epoch: 170, Loss: 5.823
# Epoch: 171, Loss: 6.034
# Epoch: 172, Loss: 4.897
# Epoch: 173, Loss: 5.782
# Epoch: 174, Loss: 5.617
# Epoch: 175, Loss: 5.090
# Epoch: 176, Loss: 5.585
# Epoch: 177, Loss: 5.110
# Epoch: 178, Loss: 4.501
# Epoch: 179, Loss: 5.526
# Epoch: 180, Loss: 4.933
# Epoch: 181, Loss: 4.668
# Epoch: 182, Loss: 4.867
# Epoch: 183, Loss: 5.007
# Epoch: 184, Loss: 5.932
# Epoch: 185, Loss: 6.149
# Epoch: 186, Loss: 4.545
# Epoch: 187, Loss: 5.259
# Epoch: 188, Loss: 5.084
# Epoch: 189, Loss: 6.298
# Epoch: 190, Loss: 4.741
# Epoch: 191, Loss: 4.683
# Epoch: 192, Loss: 4.588
# Epoch: 193, Loss: 4.722
# Epoch: 194, Loss: 4.988
# Epoch: 195, Loss: 4.584
# Epoch: 196, Loss: 4.826
# Epoch: 197, Loss: 6.029
# Epoch: 198, Loss: 5.297
# Epoch: 199, Loss: 5.219
# Epoch: 200, Loss: 5.012
# Epoch: 201, Loss: 4.692
# Epoch: 202, Loss: 5.231
# Epoch: 203, Loss: 4.446
# Epoch: 204, Loss: 4.980
# Epoch: 205, Loss: 5.197
# Epoch: 206, Loss: 5.671
# Epoch: 207, Loss: 4.494
# Epoch: 208, Loss: 4.215
# Epoch: 209, Loss: 4.967
# Epoch: 210, Loss: 4.727
# Epoch: 211, Loss: 4.834
# Epoch: 212, Loss: 4.369
# Epoch: 213, Loss: 5.007
# Epoch: 214, Loss: 4.896
# Epoch: 215, Loss: 5.681
# Epoch: 216, Loss: 4.159
# Epoch: 217, Loss: 5.108
# Epoch: 218, Loss: 4.853
# Epoch: 219, Loss: 4.975
# Epoch: 220, Loss: 4.370
# Epoch: 221, Loss: 5.097
# Epoch: 222, Loss: 5.600
# Epoch: 223, Loss: 4.631
# Epoch: 224, Loss: 4.863
# Epoch: 225, Loss: 5.570
# Epoch: 226, Loss: 4.808
# Epoch: 227, Loss: 4.810
# Epoch: 228, Loss: 4.818
# Epoch: 229, Loss: 4.840
# Epoch: 230, Loss: 4.910
# Epoch: 231, Loss: 3.871
# Epoch: 232, Loss: 3.930
# Epoch: 233, Loss: 4.655
# Epoch: 234, Loss: 4.429
# Epoch: 235, Loss: 4.449
# Epoch: 236, Loss: 5.541
# Epoch: 237, Loss: 5.387
# Epoch: 238, Loss: 4.633
# Epoch: 239, Loss: 4.884
# Epoch: 240, Loss: 3.542
# Epoch: 241, Loss: 5.157
# Epoch: 242, Loss: 5.636
# Epoch: 243, Loss: 4.386
# Epoch: 244, Loss: 5.035
# Epoch: 245, Loss: 4.531
# Epoch: 246, Loss: 5.131
# Epoch: 247, Loss: 4.248
# Epoch: 248, Loss: 4.493
# Epoch: 249, Loss: 4.896
# Epoch: 250, Loss: 4.670
# Epoch: 251, Loss: 4.710
# Epoch: 252, Loss: 4.985
# Epoch: 253, Loss: 5.372
# Epoch: 254, Loss: 4.247
# Epoch: 255, Loss: 4.736
# Epoch: 256, Loss: 5.022
# Epoch: 257, Loss: 4.974
# Epoch: 258, Loss: 4.444
# Epoch: 259, Loss: 4.131
# Epoch: 260, Loss: 4.633
# Epoch: 261, Loss: 3.725
# Epoch: 262, Loss: 4.371
# Epoch: 263, Loss: 4.901
# Epoch: 264, Loss: 5.252
# Epoch: 265, Loss: 4.403
# Epoch: 266, Loss: 4.054
# Epoch: 267, Loss: 5.558
# Epoch: 268, Loss: 4.055
# Epoch: 269, Loss: 4.225
# Epoch: 270, Loss: 4.558
# Epoch: 271, Loss: 4.560
# Epoch: 272, Loss: 5.718
# Epoch: 273, Loss: 4.915
# Epoch: 274, Loss: 4.006
# Epoch: 275, Loss: 5.056
# Epoch: 276, Loss: 4.981
# Epoch: 277, Loss: 4.481
# Epoch: 278, Loss: 4.631
# Epoch: 279, Loss: 4.923
# Epoch: 280, Loss: 4.509
# Epoch: 281, Loss: 4.330
# Epoch: 282, Loss: 4.285
# Epoch: 283, Loss: 4.972
# Epoch: 284, Loss: 4.511
# Epoch: 285, Loss: 4.109
# Epoch: 286, Loss: 4.428
# Epoch: 287, Loss: 4.300
# Epoch: 288, Loss: 5.119
# Epoch: 289, Loss: 4.150
# Epoch: 290, Loss: 4.524
# Epoch: 291, Loss: 4.895
# Epoch: 292, Loss: 4.839
# Epoch: 293, Loss: 4.446
# Epoch: 294, Loss: 4.521
# Epoch: 295, Loss: 4.252
# Epoch: 296, Loss: 4.592
# Epoch: 297, Loss: 4.118
# Epoch: 298, Loss: 4.036
# Epoch: 299, Loss: 3.922
# Epoch: 300, Loss: 4.831
# Epoch: 301, Loss: 4.317
# Epoch: 302, Loss: 4.023
# Epoch: 303, Loss: 4.223
# Epoch: 304, Loss: 4.359
# Epoch: 305, Loss: 4.447
# Epoch: 306, Loss: 4.290
# Epoch: 307, Loss: 4.870
# Epoch: 308, Loss: 4.181
# Epoch: 309, Loss: 5.011
# Epoch: 310, Loss: 4.286
# Epoch: 311, Loss: 4.707
# Epoch: 312, Loss: 3.822
# Epoch: 313, Loss: 4.510
# Epoch: 314, Loss: 4.510
# Epoch: 315, Loss: 5.240
# Epoch: 316, Loss: 4.448
# Epoch: 317, Loss: 4.693
# Epoch: 318, Loss: 3.684
# Epoch: 319, Loss: 4.139
# Epoch: 320, Loss: 4.232
# Epoch: 321, Loss: 4.350
# Epoch: 322, Loss: 4.447
# Epoch: 323, Loss: 4.758
# Epoch: 324, Loss: 4.266
# Epoch: 325, Loss: 4.029
# Epoch: 326, Loss: 4.533
# Epoch: 327, Loss: 3.934
# Epoch: 328, Loss: 3.983
# Epoch: 329, Loss: 4.243
# Epoch: 330, Loss: 4.062
# Epoch: 331, Loss: 3.893
# Epoch: 332, Loss: 4.656
# Epoch: 333, Loss: 4.093
# Epoch: 334, Loss: 4.224
# Epoch: 335, Loss: 3.794
# Epoch: 336, Loss: 4.952
# Epoch: 337, Loss: 4.132
# Epoch: 338, Loss: 4.484
# Epoch: 339, Loss: 5.118
# Epoch: 340, Loss: 4.208
# Epoch: 341, Loss: 4.778
# Epoch: 342, Loss: 4.499
# Epoch: 343, Loss: 4.622
# Epoch: 344, Loss: 4.191
# Epoch: 345, Loss: 4.951
# Epoch: 346, Loss: 3.993
# Epoch: 347, Loss: 3.673
# Epoch: 348, Loss: 4.317
# Epoch: 349, Loss: 4.421
# Epoch: 350, Loss: 4.196
# Epoch: 351, Loss: 4.605
# Epoch: 352, Loss: 4.989
# Epoch: 353, Loss: 3.735
# Epoch: 354, Loss: 4.226
# Epoch: 355, Loss: 3.995
# Epoch: 356, Loss: 4.195
# Epoch: 357, Loss: 5.457
# Epoch: 358, Loss: 4.710
# Epoch: 359, Loss: 4.397
# Epoch: 360, Loss: 4.637
# Epoch: 361, Loss: 5.261
# Epoch: 362, Loss: 4.902
# Epoch: 363, Loss: 4.200
# Epoch: 364, Loss: 4.497
# Epoch: 365, Loss: 3.841
# Epoch: 366, Loss: 4.149
# Epoch: 367, Loss: 4.292
# Epoch: 368, Loss: 4.031
# Epoch: 369, Loss: 4.612
# Epoch: 370, Loss: 3.981
# Epoch: 371, Loss: 4.835
# Epoch: 372, Loss: 4.767
# Epoch: 373, Loss: 4.423
# Epoch: 374, Loss: 4.610
# Epoch: 375, Loss: 4.258
# Epoch: 376, Loss: 4.409
# Epoch: 377, Loss: 4.302
# Epoch: 378, Loss: 4.201
# Epoch: 379, Loss: 4.665
# Epoch: 380, Loss: 4.634
# Epoch: 381, Loss: 4.432
# Epoch: 382, Loss: 4.096
# Epoch: 383, Loss: 3.789
# Epoch: 384, Loss: 4.834
# Epoch: 385, Loss: 4.126
# Epoch: 386, Loss: 3.971
# Epoch: 387, Loss: 4.508
# Epoch: 388, Loss: 4.527
# Epoch: 389, Loss: 4.771
# Epoch: 390, Loss: 4.075
# Epoch: 391, Loss: 4.262
# Epoch: 392, Loss: 4.167
# Epoch: 393, Loss: 4.010
# Epoch: 394, Loss: 3.834
# Epoch: 395, Loss: 4.060
# Epoch: 396, Loss: 4.805
# Epoch: 397, Loss: 4.254
# Epoch: 398, Loss: 3.913
# Epoch: 399, Loss: 4.343
# Epoch: 400, Loss: 4.277
# Epoch: 401, Loss: 4.248
# Epoch: 402, Loss: 4.575
# Epoch: 403, Loss: 4.741
# Epoch: 404, Loss: 3.872
# Epoch: 405, Loss: 4.213
# Epoch: 406, Loss: 3.750
# Epoch: 407, Loss: 4.332
# Epoch: 408, Loss: 4.403
# Epoch: 409, Loss: 5.261
# Epoch: 410, Loss: 4.594
# Epoch: 411, Loss: 4.104
# Epoch: 412, Loss: 4.179
# Epoch: 413, Loss: 3.962
# Epoch: 414, Loss: 4.496
# Epoch: 415, Loss: 4.328
# Epoch: 416, Loss: 3.579
# Epoch: 417, Loss: 4.714
# Epoch: 418, Loss: 4.021
# Epoch: 419, Loss: 4.922
# Epoch: 420, Loss: 5.137
# Epoch: 421, Loss: 4.485
# Epoch: 422, Loss: 3.682
# Epoch: 423, Loss: 4.033
# Epoch: 424, Loss: 4.065
# Epoch: 425, Loss: 4.289
# Epoch: 426, Loss: 4.107
# Epoch: 427, Loss: 4.213
# Epoch: 428, Loss: 4.709
# Epoch: 429, Loss: 4.178
# Epoch: 430, Loss: 4.501
# Epoch: 431, Loss: 3.993
# Epoch: 432, Loss: 3.833
# Epoch: 433, Loss: 4.056
# Epoch: 434, Loss: 4.072
# Epoch: 435, Loss: 4.356
# Epoch: 436, Loss: 4.075
# Epoch: 437, Loss: 4.437
# Epoch: 438, Loss: 4.397
# Epoch: 439, Loss: 4.187
# Epoch: 440, Loss: 4.176
# Epoch: 441, Loss: 4.797
# Epoch: 442, Loss: 4.266
# Epoch: 443, Loss: 4.011
# Epoch: 444, Loss: 3.909
# Epoch: 445, Loss: 4.275
# Epoch: 446, Loss: 3.615
# Epoch: 447, Loss: 4.090
# Epoch: 448, Loss: 4.607
# Epoch: 449, Loss: 4.438
# Epoch: 450, Loss: 4.052
# Epoch: 451, Loss: 4.335
# Epoch: 452, Loss: 4.145
# Epoch: 453, Loss: 3.817
# Epoch: 454, Loss: 4.555
# Epoch: 455, Loss: 3.948
# Epoch: 456, Loss: 4.200
# Epoch: 457, Loss: 4.476
# Epoch: 458, Loss: 4.581
# Epoch: 459, Loss: 4.240
# Epoch: 460, Loss: 4.432
# Epoch: 461, Loss: 4.072
# Epoch: 462, Loss: 4.005
# Epoch: 463, Loss: 4.657
# Epoch: 464, Loss: 4.067
# Epoch: 465, Loss: 4.400
# Epoch: 466, Loss: 4.154
# Epoch: 467, Loss: 3.949
# Epoch: 468, Loss: 3.973
# Epoch: 469, Loss: 4.559
# Epoch: 470, Loss: 3.739
# Epoch: 471, Loss: 4.406
# Epoch: 472, Loss: 3.847
# Epoch: 473, Loss: 4.379
# Epoch: 474, Loss: 4.133
# Epoch: 475, Loss: 4.356
# Epoch: 476, Loss: 4.050
# Epoch: 477, Loss: 4.433
# Epoch: 478, Loss: 4.352
# Epoch: 479, Loss: 4.474
# Epoch: 480, Loss: 4.299
# Epoch: 481, Loss: 3.907
# Epoch: 482, Loss: 3.918
# Epoch: 483, Loss: 3.653
# Epoch: 484, Loss: 4.080
# Epoch: 485, Loss: 3.712
# Epoch: 486, Loss: 4.459
# Epoch: 487, Loss: 4.213
# Epoch: 488, Loss: 4.019
# Epoch: 489, Loss: 4.181
# Epoch: 490, Loss: 4.625
# Epoch: 491, Loss: 3.691
# Epoch: 492, Loss: 5.046
# Epoch: 493, Loss: 4.384
# Epoch: 494, Loss: 4.657
# Epoch: 495, Loss: 3.983
# Epoch: 496, Loss: 4.811
# Epoch: 497, Loss: 3.720
# Epoch: 498, Loss: 4.236
# Epoch: 499, Loss: 4.161
# Epoch: 500, Loss: 4.473
# Epoch: 501, Loss: 4.706
# Epoch: 502, Loss: 3.741
# Epoch: 503, Loss: 4.261
# Epoch: 504, Loss: 3.970
# Epoch: 505, Loss: 4.597
# Epoch: 506, Loss: 4.550
# Epoch: 507, Loss: 4.698
# Epoch: 508, Loss: 3.948
# Epoch: 509, Loss: 4.495
# Epoch: 510, Loss: 3.932
# Epoch: 511, Loss: 3.894
# Epoch: 512, Loss: 4.140
# Epoch: 513, Loss: 4.332
# Epoch: 514, Loss: 4.093
# Epoch: 515, Loss: 4.315
# Epoch: 516, Loss: 4.265
# Epoch: 517, Loss: 4.326
# Epoch: 518, Loss: 3.678
# Epoch: 519, Loss: 4.086
# Epoch: 520, Loss: 4.235
# Epoch: 521, Loss: 4.255
# Epoch: 522, Loss: 3.940
# Epoch: 523, Loss: 3.898
# Epoch: 524, Loss: 3.876
# Epoch: 525, Loss: 4.101
# Epoch: 526, Loss: 4.059
# Epoch: 527, Loss: 3.567
# Epoch: 528, Loss: 4.158
# Epoch: 529, Loss: 4.324
# Epoch: 530, Loss: 4.650
# Epoch: 531, Loss: 4.236
# Epoch: 532, Loss: 4.370
# Epoch: 533, Loss: 4.367
# Epoch: 534, Loss: 4.145
# Epoch: 535, Loss: 3.972
# Epoch: 536, Loss: 4.395
# Epoch: 537, Loss: 4.209
# Epoch: 538, Loss: 4.162
# Epoch: 539, Loss: 3.772
# Epoch: 540, Loss: 3.750
# Epoch: 541, Loss: 4.103
# Epoch: 542, Loss: 4.340
# Epoch: 543, Loss: 3.975
# Epoch: 544, Loss: 4.319
# Epoch: 545, Loss: 4.633
# Epoch: 546, Loss: 4.534
# Epoch: 547, Loss: 4.453
# Epoch: 548, Loss: 4.341
# Epoch: 549, Loss: 3.714
# Epoch: 550, Loss: 4.032
# Epoch: 551, Loss: 3.660
# Epoch: 552, Loss: 4.334
# Epoch: 553, Loss: 4.631
# Epoch: 554, Loss: 4.707
# Epoch: 555, Loss: 3.541
# Epoch: 556, Loss: 4.078
# Epoch: 557, Loss: 4.017
# Epoch: 558, Loss: 4.204
# Epoch: 559, Loss: 3.835
# Epoch: 560, Loss: 3.709
# Epoch: 561, Loss: 4.209
# Epoch: 562, Loss: 3.918
# Epoch: 563, Loss: 3.876
# Epoch: 564, Loss: 4.166
# Epoch: 565, Loss: 3.671
# Epoch: 566, Loss: 4.175
# Epoch: 567, Loss: 4.070
# Epoch: 568, Loss: 4.342
# Epoch: 569, Loss: 4.428
# Epoch: 570, Loss: 4.355
# Epoch: 571, Loss: 3.778
# Epoch: 572, Loss: 3.734
# Epoch: 573, Loss: 4.138
# Epoch: 574, Loss: 4.268
# Epoch: 575, Loss: 4.230
# Epoch: 576, Loss: 3.915
# Epoch: 577, Loss: 4.173
# Epoch: 578, Loss: 3.773
# Epoch: 579, Loss: 4.211
# Epoch: 580, Loss: 4.561
# Epoch: 581, Loss: 4.158
# Epoch: 582, Loss: 3.775
# Epoch: 583, Loss: 4.121
# Epoch: 584, Loss: 4.653
# Epoch: 585, Loss: 3.892
# Epoch: 586, Loss: 4.305
# Epoch: 587, Loss: 4.241
# Epoch: 588, Loss: 4.287
# Epoch: 589, Loss: 4.097
# Epoch: 590, Loss: 4.048
# Epoch: 591, Loss: 4.060
# Epoch: 592, Loss: 4.214
# Epoch: 593, Loss: 3.949
# Epoch: 594, Loss: 4.023
# Epoch: 595, Loss: 3.696
# Epoch: 596, Loss: 4.162
# Epoch: 597, Loss: 4.124
# Epoch: 598, Loss: 3.846
# Epoch: 599, Loss: 4.660
# Epoch: 600, Loss: 3.928
# Epoch: 601, Loss: 3.995
# Epoch: 602, Loss: 4.471
# Epoch: 603, Loss: 4.269
# Epoch: 604, Loss: 4.160
# Epoch: 605, Loss: 4.051
# Epoch: 606, Loss: 3.683
# Epoch: 607, Loss: 4.479
# Epoch: 608, Loss: 3.992
# Epoch: 609, Loss: 4.194
# Epoch: 610, Loss: 3.882
# Epoch: 611, Loss: 4.130
# Epoch: 612, Loss: 4.613
# Epoch: 613, Loss: 4.282
# Epoch: 614, Loss: 3.885
# Epoch: 615, Loss: 4.599
# Epoch: 616, Loss: 3.584
# Epoch: 617, Loss: 4.221
# Epoch: 618, Loss: 3.961
# Epoch: 619, Loss: 3.686
# Epoch: 620, Loss: 4.424
# Epoch: 621, Loss: 4.006
# Epoch: 622, Loss: 3.968
# Epoch: 623, Loss: 4.532
# Epoch: 624, Loss: 4.063
# Epoch: 625, Loss: 4.511
# Epoch: 626, Loss: 3.884
# Epoch: 627, Loss: 4.076
# Epoch: 628, Loss: 3.714
# Epoch: 629, Loss: 4.424
# Epoch: 630, Loss: 4.247
# Epoch: 631, Loss: 4.170
# Epoch: 632, Loss: 4.354
# Epoch: 633, Loss: 3.926
# Epoch: 634, Loss: 3.696
# Epoch: 635, Loss: 4.210
# Epoch: 636, Loss: 3.332
# Epoch: 637, Loss: 3.685
# Epoch: 638, Loss: 4.066
# Epoch: 639, Loss: 4.542
# Epoch: 640, Loss: 4.126
# Epoch: 641, Loss: 3.728
# Epoch: 642, Loss: 4.236
# Epoch: 643, Loss: 3.924
# Epoch: 644, Loss: 4.517
# Epoch: 645, Loss: 3.571
# Epoch: 646, Loss: 4.034
# Epoch: 647, Loss: 3.828
# Epoch: 648, Loss: 4.505
# Epoch: 649, Loss: 3.677
# Epoch: 650, Loss: 4.239
# Epoch: 651, Loss: 3.875
# Epoch: 652, Loss: 4.635
# Epoch: 653, Loss: 3.749
# Epoch: 654, Loss: 3.874
# Epoch: 655, Loss: 3.301
# Epoch: 656, Loss: 3.729
# Epoch: 657, Loss: 3.989
# Epoch: 658, Loss: 3.740
# Epoch: 659, Loss: 3.777
# Epoch: 660, Loss: 4.103
# Epoch: 661, Loss: 3.806
# Epoch: 662, Loss: 4.181
# Epoch: 663, Loss: 3.927
# Epoch: 664, Loss: 3.995
# Epoch: 665, Loss: 3.914
# Epoch: 666, Loss: 4.287
# Epoch: 667, Loss: 3.721
# Epoch: 668, Loss: 4.219
# Epoch: 669, Loss: 3.826
# Epoch: 670, Loss: 3.598
# Epoch: 671, Loss: 4.423
# Epoch: 672, Loss: 4.519
# Epoch: 673, Loss: 3.595
# Epoch: 674, Loss: 4.362
# Epoch: 675, Loss: 3.478
# Epoch: 676, Loss: 3.571
# Epoch: 677, Loss: 4.425
# Epoch: 678, Loss: 3.696
# Epoch: 679, Loss: 4.451
# Epoch: 680, Loss: 4.022
# Epoch: 681, Loss: 4.091
# Epoch: 682, Loss: 4.745
# Epoch: 683, Loss: 4.074
# Epoch: 684, Loss: 3.782
# Epoch: 685, Loss: 4.531
# Epoch: 686, Loss: 3.819
# Epoch: 687, Loss: 3.704
# Epoch: 688, Loss: 4.163
# Epoch: 689, Loss: 4.052
# Epoch: 690, Loss: 4.233
# Epoch: 691, Loss: 3.543
# Epoch: 692, Loss: 4.380
# Epoch: 693, Loss: 4.070
# Epoch: 694, Loss: 4.331
# Epoch: 695, Loss: 3.769
# Epoch: 696, Loss: 3.645
# Epoch: 697, Loss: 3.483
# Epoch: 698, Loss: 3.982
# Epoch: 699, Loss: 4.164
# Epoch: 700, Loss: 4.055
# Epoch: 701, Loss: 3.638
# Epoch: 702, Loss: 4.146
# Epoch: 703, Loss: 4.066
# Epoch: 704, Loss: 3.469
# Epoch: 705, Loss: 3.882
# Epoch: 706, Loss: 4.242
# Epoch: 707, Loss: 4.291
# Epoch: 708, Loss: 3.878
# Epoch: 709, Loss: 3.735
# Epoch: 710, Loss: 3.762
# Epoch: 711, Loss: 4.414
# Epoch: 712, Loss: 4.033
# Epoch: 713, Loss: 3.884
# Epoch: 714, Loss: 3.992
# Epoch: 715, Loss: 3.863
# Epoch: 716, Loss: 4.200
# Epoch: 717, Loss: 3.393
# Epoch: 718, Loss: 3.985
# Epoch: 719, Loss: 5.022
# Epoch: 720, Loss: 4.467
# Epoch: 721, Loss: 4.265
# Epoch: 722, Loss: 3.887
# Epoch: 723, Loss: 3.567
# Epoch: 724, Loss: 3.943
# Epoch: 725, Loss: 3.934
# Epoch: 726, Loss: 4.255
# Epoch: 727, Loss: 3.958
# Epoch: 728, Loss: 3.739
# Epoch: 729, Loss: 3.853
# Epoch: 730, Loss: 3.930
# Epoch: 731, Loss: 3.593
# Epoch: 732, Loss: 3.524
# Epoch: 733, Loss: 3.651
# Epoch: 734, Loss: 4.044
# Epoch: 735, Loss: 3.728
# Epoch: 736, Loss: 3.911
# Epoch: 737, Loss: 3.786
# Epoch: 738, Loss: 4.220
# Epoch: 739, Loss: 3.973
# Epoch: 740, Loss: 3.602
# Epoch: 741, Loss: 3.833
# Epoch: 742, Loss: 4.077
# Epoch: 743, Loss: 4.082
# Epoch: 744, Loss: 3.662
# Epoch: 745, Loss: 3.436
# Epoch: 746, Loss: 4.031
# Epoch: 747, Loss: 4.280
# Epoch: 748, Loss: 4.496
# Epoch: 749, Loss: 4.098
# Epoch: 750, Loss: 3.355
# Epoch: 751, Loss: 3.875
# Epoch: 752, Loss: 3.879
# Epoch: 753, Loss: 3.922
# Epoch: 754, Loss: 4.294
# Epoch: 755, Loss: 4.146
# Epoch: 756, Loss: 3.607
# Epoch: 757, Loss: 3.589
# Epoch: 758, Loss: 4.087
# Epoch: 759, Loss: 4.450
# Epoch: 760, Loss: 4.187
# Epoch: 761, Loss: 4.697
# Epoch: 762, Loss: 4.431
# Epoch: 763, Loss: 3.977
# Epoch: 764, Loss: 4.215
# Epoch: 765, Loss: 4.164
# Epoch: 766, Loss: 3.613
# Epoch: 767, Loss: 4.314
# Epoch: 768, Loss: 3.521
# Epoch: 769, Loss: 4.053
# Epoch: 770, Loss: 3.476
# Epoch: 771, Loss: 4.448
# Epoch: 772, Loss: 4.072
# Epoch: 773, Loss: 3.970
# Epoch: 774, Loss: 4.006
# Epoch: 775, Loss: 4.169
# Epoch: 776, Loss: 3.996
# Epoch: 777, Loss: 3.850
# Epoch: 778, Loss: 3.978
# Epoch: 779, Loss: 4.236
# Epoch: 780, Loss: 3.755
# Epoch: 781, Loss: 3.660
# Epoch: 782, Loss: 3.759
# Epoch: 783, Loss: 3.959
# Epoch: 784, Loss: 4.227
# Epoch: 785, Loss: 3.874
# Epoch: 786, Loss: 3.546
# Epoch: 787, Loss: 3.267
# Epoch: 788, Loss: 4.102
# Epoch: 789, Loss: 3.655
# Epoch: 790, Loss: 4.034
# Epoch: 791, Loss: 3.975
# Epoch: 792, Loss: 3.519
# Epoch: 793, Loss: 3.274
# Epoch: 794, Loss: 4.194
# Epoch: 795, Loss: 3.525
# Epoch: 796, Loss: 4.165
# Epoch: 797, Loss: 4.303
# Epoch: 798, Loss: 3.833
# Epoch: 799, Loss: 3.705
# Epoch: 800, Loss: 3.545
# Epoch: 801, Loss: 3.844
# Epoch: 802, Loss: 3.281
# Epoch: 803, Loss: 3.994
# Epoch: 804, Loss: 3.920
# Epoch: 805, Loss: 4.187
# Epoch: 806, Loss: 3.483
# Epoch: 807, Loss: 3.490
# Epoch: 808, Loss: 3.887
# Epoch: 809, Loss: 3.969
# Epoch: 810, Loss: 4.041
# Epoch: 811, Loss: 3.803
# Epoch: 812, Loss: 3.964
# Epoch: 813, Loss: 3.773
# Epoch: 814, Loss: 3.804
# Epoch: 815, Loss: 3.769
# Epoch: 816, Loss: 4.476
# Epoch: 817, Loss: 3.918
# Epoch: 818, Loss: 3.990
# Epoch: 819, Loss: 4.161
# Epoch: 820, Loss: 4.267
# Epoch: 821, Loss: 3.577
# Epoch: 822, Loss: 3.723
# Epoch: 823, Loss: 3.290
# Epoch: 824, Loss: 3.876
# Epoch: 825, Loss: 3.689
# Epoch: 826, Loss: 4.016
# Epoch: 827, Loss: 3.737
# Epoch: 828, Loss: 4.196
# Epoch: 829, Loss: 4.088
# Epoch: 830, Loss: 4.156
# Epoch: 831, Loss: 4.392
# Epoch: 832, Loss: 3.681
# Epoch: 833, Loss: 4.140
# Epoch: 834, Loss: 3.744
# Epoch: 835, Loss: 3.730
# Epoch: 836, Loss: 3.643
# Epoch: 837, Loss: 4.034
# Epoch: 838, Loss: 3.516
# Epoch: 839, Loss: 4.425
# Epoch: 840, Loss: 3.892
# Epoch: 841, Loss: 3.599
# Epoch: 842, Loss: 3.920
# Epoch: 843, Loss: 3.769
# Epoch: 844, Loss: 3.879
# Epoch: 845, Loss: 3.791
# Epoch: 846, Loss: 3.649
# Epoch: 847, Loss: 3.703
# Epoch: 848, Loss: 4.055
# Epoch: 849, Loss: 3.564
# Epoch: 850, Loss: 4.230
# Epoch: 851, Loss: 3.807
# Epoch: 852, Loss: 4.488
# Epoch: 853, Loss: 4.408
# Epoch: 854, Loss: 4.156
# Epoch: 855, Loss: 3.777
# Epoch: 856, Loss: 3.992
# Epoch: 857, Loss: 3.615
# Epoch: 858, Loss: 3.899
# Epoch: 859, Loss: 3.974
# Epoch: 860, Loss: 3.801
# Epoch: 861, Loss: 3.472
# Epoch: 862, Loss: 3.494
# Epoch: 863, Loss: 4.160
# Epoch: 864, Loss: 3.875
# Epoch: 865, Loss: 3.956
# Epoch: 866, Loss: 3.818
# Epoch: 867, Loss: 4.256
# Epoch: 868, Loss: 4.545
# Epoch: 869, Loss: 3.814
# Epoch: 870, Loss: 4.120
# Epoch: 871, Loss: 3.328
# Epoch: 872, Loss: 3.699
# Epoch: 873, Loss: 3.658
# Epoch: 874, Loss: 3.918
# Epoch: 875, Loss: 4.015
# Epoch: 876, Loss: 3.813
# Epoch: 877, Loss: 3.652
# Epoch: 878, Loss: 4.389
# Epoch: 879, Loss: 3.910
# Epoch: 880, Loss: 3.847
# Epoch: 881, Loss: 4.206
# Epoch: 882, Loss: 3.013
# Epoch: 883, Loss: 3.811
# Epoch: 884, Loss: 3.999
# Epoch: 885, Loss: 3.646
# Epoch: 886, Loss: 3.728
# Epoch: 887, Loss: 3.640
# Epoch: 888, Loss: 3.977
# Epoch: 889, Loss: 4.352
# Epoch: 890, Loss: 4.049
# Epoch: 891, Loss: 3.751
# Epoch: 892, Loss: 3.777
# Epoch: 893, Loss: 3.455
# Epoch: 894, Loss: 4.247
# Epoch: 895, Loss: 3.867
# Epoch: 896, Loss: 3.236
# Epoch: 897, Loss: 4.238
# Epoch: 898, Loss: 4.265
# Epoch: 899, Loss: 3.338
# Epoch: 900, Loss: 4.110
# Epoch: 901, Loss: 4.544
# Epoch: 902, Loss: 3.355
# Epoch: 903, Loss: 3.366
# Epoch: 904, Loss: 3.649
# Epoch: 905, Loss: 3.482
# Epoch: 906, Loss: 3.849
# Epoch: 907, Loss: 4.059
# Epoch: 908, Loss: 4.133
# Epoch: 909, Loss: 4.289
# Epoch: 910, Loss: 3.553
# Epoch: 911, Loss: 3.978
# Epoch: 912, Loss: 3.592
# Epoch: 913, Loss: 3.617
# Epoch: 914, Loss: 4.244
# Epoch: 915, Loss: 3.655
# Epoch: 916, Loss: 3.715
# Epoch: 917, Loss: 3.855
# Epoch: 918, Loss: 3.957
# Epoch: 919, Loss: 3.415
# Epoch: 920, Loss: 3.632
# Epoch: 921, Loss: 3.808
# Epoch: 922, Loss: 4.669
# Epoch: 923, Loss: 3.552
# Epoch: 924, Loss: 3.976
# Epoch: 925, Loss: 4.084
# Epoch: 926, Loss: 3.648
# Epoch: 927, Loss: 4.414
# Epoch: 928, Loss: 3.807
# Epoch: 929, Loss: 4.184
# Epoch: 930, Loss: 4.235
# Epoch: 931, Loss: 3.932
# Epoch: 932, Loss: 4.165
# Epoch: 933, Loss: 3.476
# Epoch: 934, Loss: 3.737
# Epoch: 935, Loss: 3.967
# Epoch: 936, Loss: 3.898
# Epoch: 937, Loss: 3.996
# Epoch: 938, Loss: 3.848
# Epoch: 939, Loss: 3.709
# Epoch: 940, Loss: 3.025
# Epoch: 941, Loss: 3.730
# Epoch: 942, Loss: 3.878
# Epoch: 943, Loss: 3.495
# Epoch: 944, Loss: 3.617
# Epoch: 945, Loss: 4.164
# Epoch: 946, Loss: 3.701
# Epoch: 947, Loss: 3.970
# Epoch: 948, Loss: 3.980
# Epoch: 949, Loss: 3.570
# Epoch: 950, Loss: 3.933
# Epoch: 951, Loss: 4.259
# Epoch: 952, Loss: 3.536
# Epoch: 953, Loss: 4.295
# Epoch: 954, Loss: 3.510
# Epoch: 955, Loss: 3.592
# Epoch: 956, Loss: 4.279
# Epoch: 957, Loss: 3.455
# Epoch: 958, Loss: 3.631
# Epoch: 959, Loss: 3.648
# Epoch: 960, Loss: 3.898
# Epoch: 961, Loss: 4.133
# Epoch: 962, Loss: 3.712
# Epoch: 963, Loss: 3.191
# Epoch: 964, Loss: 4.269
# Epoch: 965, Loss: 3.927
# Epoch: 966, Loss: 3.388
# Epoch: 967, Loss: 3.743
# Epoch: 968, Loss: 3.867
# Epoch: 969, Loss: 4.194
# Epoch: 970, Loss: 3.592
# Epoch: 971, Loss: 4.324
# Epoch: 972, Loss: 3.950
# Epoch: 973, Loss: 3.804
# Epoch: 974, Loss: 3.696
# Epoch: 975, Loss: 4.194
# Epoch: 976, Loss: 3.431
# Epoch: 977, Loss: 3.863
# Epoch: 978, Loss: 3.488
# Epoch: 979, Loss: 4.215
# Epoch: 980, Loss: 3.903
# Epoch: 981, Loss: 4.478
# Epoch: 982, Loss: 4.542
# Epoch: 983, Loss: 3.778
# Epoch: 984, Loss: 3.613
# Epoch: 985, Loss: 3.888
# Epoch: 986, Loss: 3.754
# Epoch: 987, Loss: 3.765
# Epoch: 988, Loss: 4.082
# Epoch: 989, Loss: 3.533
# Epoch: 990, Loss: 3.786
# Epoch: 991, Loss: 4.131
# Epoch: 992, Loss: 3.532
# Epoch: 993, Loss: 4.433
# Epoch: 994, Loss: 4.066
# Epoch: 995, Loss: 3.836
# Epoch: 996, Loss: 4.129
# Epoch: 997, Loss: 4.391
# Epoch: 998, Loss: 3.599
# Epoch: 999, Loss: 3.854
# Epoch: 1000, Loss: 3.257
